# %%
import pandas as pd
import numpy as np
from sklearn.cluster import k_means

# %% [markdown]
# # K-means

# %%
df = pd.read_csv('phones_2024.csv')
df.head(20)
# Out:
#     Unnamed: 0                                   Model    Price  Rating  \
# 0            0                              iQOO Z9 5G  ₹19,999     NaN
# 1            1                        Nothing Phone 2a  ₹23,999     NaN
# 2            2                         Vivo V30 Pro 5G  ₹41,999     NaN
# 3            3                             Vivo V30 5G  ₹33,999     NaN
# 4            4                       Realme 12 Plus 5G  ₹19,999     NaN
# 5            5                         Oppo F25 Pro 5G  ₹23,999     NaN
# 6            6                   Samsung Galaxy F15 5G  ₹12,999    75.0
# 7            7                    OnePlus Nord CE 3 5G  ₹22,429     NaN
# 8            8             Xiaomi Redmi Note 13 Pro 5G  ₹23,630     NaN
# 9            9  Motorola Moto G34 5G (8GB RAM + 128GB)  ₹11,999    77.0
# 10          10                    Motorola Edge 40 Neo  ₹22,999     NaN
# 11          11                             OnePlus 12R  ₹38,300     NaN
# ...

# %% [markdown]
# # G-means
