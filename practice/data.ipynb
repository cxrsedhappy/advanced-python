# %% [markdown]
# # Matplotlib
# Для работы с библиотекой **matplotlib** нужно

# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Визуализация
#
# С помощью библиотеки мы можем визуализировать функции в виде графиков.
#
# Визуализируем 2 функции и косинус с синусом с помощью функции **plot()**
#
# Первая квадратичная функция:
#
# $$
# F(x) = x^2 - 2x - 10
# $$
#
# Вторая квадратичная функция:
#
# $$
# G(x) = x^2 - 10
# $$

# %%
def f(_x: float) -> float:
    return _x ** 2 - 2 * _x - 10

def g(_x: float) -> float:
    return _x ** 2 - 10

x = np.linspace(-3, 3)
x1 = np.linspace(0, np.pi * 4)
y = np.array([4, 7, 2, 1, 3, 5, 6, 2, 9, 5])

figure, ax = plt.subplots(1, 2)

figure.set_figheight(4)
figure.set_figwidth(10)

ax[0].plot(x1, np.sin(x1), c='red', linewidth=1.2, label='sin(x)')
ax[0].plot(x1, np.cos(x1), c='blue', linewidth=1.2, label='cos(x)')
ax[0].set_xlim(1, 9)
ax[0].set_ylim(-2, 2)
ax[0].set(xticks=np.arange(min(x1), max(x1) + 1, np.pi), xticklabels=['0', 'pi', '2pi', '3pi', '4pi'])

ax[1].plot(x, f(x), c='black', linestyle='--', label='f(x)')
ax[1].plot(x, g(x), c='#FFDD44', marker='.', label='g(x)')
ax[1].set_xlim(-5, 5)
ax[1].set_ylim(-12, 4)

ax[1].set_title('Test equations')
ax[0].legend(loc='lower left')
ax[1].legend(loc='lower left')
plt.show()

# %% [markdown]
# ### Производная
#
# Производная (англ. [derivative](https://www.youtube.com/shorts/PGK-RXA8Ye8)) показывает насколько функция возрастает или убывает.
#
# В данном примере имеется функция $ F(x) = x^2 + 4x - 2 $ и ее производная $ F'(x) = 2x + 4 $

# %%
def f(_x):
    return _x ** 2 + 4 * x - 2

def df(_x):
    return 2 * _x + 4


x = np.linspace(-3, 3)

figure = plt.figure(figsize=(10, 4))

plt.plot(x, f(x))
plt.plot(x, df(x))
plt.show()
